# %%
#Packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Squad analysis
print("This is data for your current squad.")
df = pd.read_html(r"Attributes.html", skiprows=0)[0]
# Out:
# This is data for your current squad.

# %%
# Set DataFrame limits
pd.set_option('display.max_columns',50)
pd.set_option('display.max_rows',5)

# %%
#Creating score for every position role and club DNA
df['Club DNA'] = df['Agg'] + df['Ldr'] + df['Det'] + df['Tea'] + df['Wor'] ##What I look for in players
df['Goalkeeper'] = df['1v1'] + df['Aer'] + df['Agi'] + df['Cmd'] + df['Com'] + df['Han'] + df['Kic'] + df['Pos'] + df['Ref'] + df['Thr']
df['Sweeper Keeper'] = df['1v1'] + df['Aer'] + df['Agi'] + df['Cmd'] + df['Com'] + df['Han'] + df['Kic'] + df['Pos'] + df['Ref'] + df['Thr'] + df['Cmp'] + df['Fir'] + df['Pas'] + df['TRO'] + df['Acc'] + df['Vis']

#Centre Back
df['Wide Centre Back'] = df['Fir'] + df['Hea'] + df['Mar'] + df['Pas'] + df['Tck'] + df['Agg'] + df['Ant'] + df['Bra'] + df['Cmp'] + df['Cnt'] + df['Dec'] + df['OtB'] + df['Pos'] + df['Wor'] + df['Jum'] + df['Pac'] + df['Sta'] + df['Str']
df['Central Defender'] = df['Hea'] + df['Mar'] + df['Tck'] + df['Agg'] + df['Ant'] + df['Bra'] + df['Cmp'] + df['Cnt'] + df['Dec'] + df['Pos'] + df['Jum'] + df['Pac'] + df['Str']
df['Libero'] = df['Dri'] + df['Fir'] + df['Hea'] + df['Lon'] + df['Mar'] + df['Pas'] + df['Tck'] + df['Tec'] + df['Ant'] + df['Bra'] + df['Cmp'] + df['Cnt'] + df['Dec'] + df['Fla'] + df['Pos'] + df['Tea'] + df['Vis'] + df['Acc'] + df['Agi'] + df['Bal'] + df['Jum'] + df['Pac'] + df['Sta'] + df['Str']
df['Ball-Playing Defender'] = df['Fir'] + df['Hea'] + df['Mar'] + df['Pas'] + df['Tck'] + df['Tec'] + df['Agg'] + df['Ant'] + df['Bra'] + df['Cmp'] + df['Cnt'] + df['Dec'] + df['Pos'] + df['Vis'] + df['Jum'] + df['Pac'] + df['Str']
df['No-Nonsense Centre Back'] = df['Hea'] + df['Mar'] + df['Tck'] + df['Agg'] + df['Ant'] + df['Bra'] + df['Cmp'] + df['Cnt'] + df['Pos'] + df['Jum'] + df['Pac'] + df['Str']

#Fullbacks
df['Full-Back'] = df['Cro'] + df['Dri'] + df['Fir'] + df['Mar'] + df['Pas'] + df['Tec'] + df['Tck'] + df['Ant'] + df['Cmp'] + df['Dec'] + df['OtB'] + df['Tea'] + df['Wor'] + df['Acc'] + df['Agi'] + df['Pac'] + df['Sta']
df['Wing-Back'] = df['Cro'] + df['Dri'] + df['Fir'] + df['Mar'] + df['Pas'] + df['Tec'] + df['Tck'] + df['Ant'] + df['Cnt'] + df['Dec'] + df['OtB'] + df['Pos'] + df['Tea'] + df['Wor'] + df['Acc'] + df['Agi'] + df['Pac'] + df['Sta']
df['No-Nonsense Full-Back'] = df['Hea'] + df['Mar'] + df['Tck'] + df['Agg'] + df['Ant'] + df['Bra'] + df['Cnt'] + df['Pos'] + df['Tea'] + df['Str']
df['Complete Wing-Back'] = df['Cro'] + df['Dri'] + df['Fir'] + df['Pas'] + df['Tec'] + df['Tck'] + df['Ant'] + df['Cmp'] + df['Dec'] + df['Fla'] + df['OtB'] + df['Tea'] + df['Wor'] + df['Acc'] + df['Agi'] + df['Pac'] + df['Sta']
df['Inverted Wing-Back'] = df['Dri'] + df['Fir'] + df['Mar'] + df['Pas'] + df['Tec'] + df['Tck']  + df['Ant'] + df['Cmp'] +df['Cnt'] + df['Dec'] + df['OtB'] + df['Pos'] + df['Tea'] + df['Wor'] + df['Acc'] + df['Agi'] + df['Sta']
df['Inverted Full-Back'] = df['Hea'] + df['Mar'] + df['Tck'] + df['Ant'] + df['Cmp'] + df['Cnt'] + df['Dec'] + df['Pos'] + df['Wor'] + df['Str']

#Midfield
df['Defensive Midfielder'] = df['Fir'] + df['Mar'] + df['Pas'] + df['Tck'] + df['Agg'] + df['Ant'] + df['Cmp'] + df['Cnt'] + df['Dec'] + df['Pos'] + df['Tea'] + df['Wor'] + df['Sta'] + df['Str']
df['Deep-Lying Playmaker'] = df['Fir'] + df['Pas'] + df['Tec'] + df['Ant'] + df['Cmp'] + df['Dec'] + df['OtB'] + df['Tea'] + df['Vis'] + df['Wor'] + df['Bal']
df['Ball-Winnining Midfielder'] = df['Mar'] + df['Tck'] + df['Agg'] + df['Ant'] + df['Bra'] + df['Cnt'] + df['Pos'] + df['Tea'] + df['Wor'] + df['Agi'] + df['Pac'] + df['Sta'] + df['Str']
df['Anchor Man'] = df['Mar'] + df['Tck'] + df['Ant'] + df['Cmp'] + df['Cnt'] + df['Dec'] + df['Pos'] + df['Tea'] + df['Str']
df['Half Back'] = df['Fir'] + df['Mar'] + df['Pas'] + df['Tck'] + df['Tec'] + df['Agg'] + df['Ant'] + df['Cmp'] + df['Cnt'] + df['Dec'] + df['Pos'] + df['Tea'] + df['Wor'] + df['Sta']
df['Regista'] = df['Dri'] + df['Fir'] + df['Lon'] + df['Pas'] + df['Tec'] + df['Ant'] + df['Cmp'] + df['Dec'] + df['Fla'] + df['OtB'] + df['Tea'] + df['Vis'] + df['Bal']
df['Roaming Playmaker'] = df['Dri'] + df['Fir'] + df['Lon'] + df['Pas'] + df['Tec'] + df['Ant'] + df['Cmp'] + df['Cnt'] + df['Dec'] + df['OtB'] + df['Pos'] + df['Tea'] + df['Vis'] + df['Wor'] + df['Acc'] + df['Agi'] + df['Bal'] + df['Pac'] + df['Sta']
df['Segundo Volante'] = df['Fin'] + df['Fir'] + df['Lon'] + df['Mar'] + df['Pas'] + df['Tck'] + df['Ant'] + df['Cmp'] + df['Cnt'] + df['Dec'] + df['OtB'] + df['Pos'] + df['Wor'] + df['Acc'] + df['Bal'] + df['Pac'] + df['Sta'] + df['Str']
df['Central Midfielder'] = df['Fir'] + df['Lon'] + df['Pas'] + df['Tck'] + df['Tec'] + df['Ant'] + df['Cmp'] + df['Dec'] + df['OtB'] + df['Tea'] + df['Vis'] + df['Wor'] + df['Acc'] + df['Sta']
df['Box-To-Box Midfielder'] = df['Dri'] + df['Fin'] + df['Fir'] + df['Lon'] + df['Pas'] + df['Tck'] + df['Tec'] + df['Agg'] + df['Ant'] + df['Cmp'] + df['Dec'] + df['OtB'] + df['Pos'] + df['Tea'] + df['Vis'] + df['Wor'] + df['Acc'] + df['Bal'] + df['Pac'] + df['Sta'] + df['Str']
df['Advanced Playmaker'] = df['Dri'] + df['Fir'] + df['Pas'] + df['Tec'] + df['Ant'] + df['Cmp'] + df['Dec'] + df['Fla'] + df['OtB'] + df['Tea'] + df['Vis'] + df['Acc'] + df['Agi']
df['Mezzala'] = df['Dri'] + df['Fin'] + df['Fir'] + df['Lon'] + df['Pas'] + df['Tec'] + df['Ant'] + df['Cmp'] + df['Dec'] + df['Fla'] + df['OtB'] + df['Vis'] + df['Wor'] + df['Acc'] + df['Bal'] + df['Sta']
df['Carrilero'] = df['Fir'] + df['Pas'] + df['Tck'] + df['Tec'] + df['Ant'] + df['Cmp'] + df['Cnt'] + df['Dec'] + df['OtB'] + df['Pos'] + df['Tea'] + df['Vis'] + df['Wor'] + df['Sta']
df['Attacking Midfielder'] = df['Dri'] + df['Fir'] + df['Lon'] + df['Pas'] + df['Tec'] + df['Ant'] + df['Cmp'] + df['Dec'] + df['Fla'] + df['OtB'] + df['Vis'] + df['Agi']
df['Terquartista'] = df['Dri'] + df['Fin'] + df['Fir'] + df['Pas'] + df['Tec'] + df['Ant'] + df['Cmp'] + df['Dec'] + df['Fla'] + df['OtB'] + df['Vis'] + df['Acc'] + df['Agi'] + df['Bal']
df['Enganche'] = df['Fir'] + df['Pas'] + df['Tec'] + df['Ant'] + df['Cmp'] + df['Dec'] + df['Fla'] + df['OtB'] + df['Vis'] + df['Bal']
df['Shadow Striker'] = df['Dri'] + df['Fin'] + df['Fir'] + df['Pas'] + df['Tec'] + df['Ant'] + df['Cmp'] + df['Cnt'] + df['Dec'] + df['OtB'] + df['Wor'] + df['Acc'] + df['Agi'] + df['Bal'] + df['Pac'] + df['Sta']

#Flanks
df['Wide Midfielder'] = df['Cro'] + df['Fir'] + df['Pas'] + df['Tck'] + df['Tec'] + df['Ant'] + df['Cmp'] + df['Cnt'] + df['Dec'] + df['OtB'] + df['Pos'] + df['Tea'] + df['Vis'] + df['Wor'] + df['Sta']
df['Winger'] = df['Cro'] + df['Dri'] + df['Fir'] + df['Pas'] + df['Tec'] + df['Ant'] + df['Fla'] + df['OtB'] + df['Wor'] + df['Acc'] + df['Agi'] + df['Bal'] + df['Pac'] + df['Sta']
df['Defensive Winger'] = df['Cro'] + df['Dri'] + df['Fir'] + df['Mar'] + df['Pas'] + df['Tec'] + df['Tck'] + df['Agg'] + df['Ant'] + df['Cmp'] + df['Cnt'] + df['Dec'] + df['OtB'] + df['Pos'] + df['Tea'] + df['Wor'] + df['Acc'] + df['Sta']
df['Wide Playmaker'] = df['Dri'] + df['Fir'] + df['Pas'] + df['Tec'] + df['Ant'] + df['Cmp'] + df['Dec'] + df['Fla'] + df['OtB'] + df['Tea'] + df['Vis'] + df['Acc'] + df['Agi']
df['Inverted Winger'] = df['Cro'] + df['Dri'] + df['Fir'] + df['Lon'] + df['Pas'] + df['Tec'] + df['Ant'] + df['Cmp'] + df['Dec'] + df['Fla'] + df['OtB'] + df['Vis'] + df['Wor'] + df['Acc'] + df['Agi'] + df['Bal'] + df['Pac'] + df['Sta']
df['Inside Forward'] = df['Dri'] + df['Fin'] + df['Fir'] + df['Lon'] + df['Pas'] + df['Tec'] + df['Ant'] + df['Cmp'] + df['Fla'] + df['OtB'] + df['Wor'] + df['Acc'] + df['Agi'] + df['Bal'] + df['Pac'] + df['Sta']
df['Wide Target Man'] = df['Cro'] + df['Fin'] + df['Fir'] + df['Hea'] + df['Ant'] + df['Bra'] + df['OtB'] + df['Tea'] + df['Wor'] + df['Bal'] + df['Jum'] + df['Sta'] + df['Str']
df['Raumdeuter'] = df['Fin'] + df['Fir'] + df['Tec'] + df['Ant'] + df['Cmp'] + df['Cnt'] + df['Dec'] + df['OtB'] + df['Wor'] + df['Acc'] + df['Bal'] + df['Sta']

#Attack
df['Deep-Lying Forward'] = df['Fin'] + df['Fir'] + df['Pas'] + df['Tec'] + df['Ant'] + df['Cmp'] + df['Dec'] + df['Fla'] + df['OtB'] + df['Tea'] + df['Vis'] + df['Bal'] + df['Str']
df['Advanced Forward'] = df['Dri'] + df['Fin'] + df['Fir'] + df['Pas'] + df['Tec'] + df['Ant'] + df['Cmp'] + df['Dec']  + df['OtB'] + df['Wor'] + df['Acc'] + df['Agi'] + df['Bal'] + df['Pac'] + df['Sta']
df['Target Forward'] = df['Fin'] + df['Fir'] + df['Hea'] + df['Agg'] + df['Ant'] + df['Bra'] + df['Cmp'] + df['Dec'] + df['OtB'] + df['Tea'] + df['Bal'] + df['Jum'] + df['Str']
df['False 9'] = df['Dri'] + df['Fin'] + df['Fir'] + df['Pas'] + df['Tec'] + df['Ant'] + df['Cmp'] + df['Dec'] + df['Fla'] + df['OtB'] + df['Tea'] + df['Vis'] + df['Acc'] + df['Agi'] + df['Bal']
df['Poacher'] = df['Fin'] + df['Fir'] + df['Hea'] + df['Tec'] + df['Ant'] + df['Cmp'] + df['Dec'] + df['OtB'] + df['Acc']
df['Complete Forward'] = df['Dri'] + df['Fin'] + df['Fir'] + df['Hea'] + df['Lon'] + df['Pas'] + df['Tec'] + df['Ant'] + df['Cmp'] + df['Dec'] + df['OtB'] + df['Tea'] + df['Vis'] + + df['Wor'] + df['Acc'] + df['Agi'] + df['Bal'] + df['Jum'] + df['Pac'] + df['Sta'] + df['Str']
df['Pressing Forward'] = df['Fin'] + df['Fir'] + df['Agg'] + df['Ant'] + df['Bra'] + df['Cmp'] + df['Cnt'] + df['Dec'] + df['OtB'] + df['Tea'] + df['Wor'] + df['Acc'] + df['Agi'] + df['Bal'] + df['Pac'] + df['Sta'] + df['Str']

# %%
#Creating columns for the roles and DNA

##Club DNA
dna = df[['Name', 'Age', 'Agg' , 'Det' ,'Ldr', 'Tea' , 'Wor', 'Club DNA']]

##Keepers
goalkeeper = df[['Name', 'Age', '1v1', 'Aer', 'Agi', 'Cmd', 'Com', 'Han', 'Kic', 'Pos', 'Ref', 'Thr', 'Goalkeeper']]
sweeper_keeper = df[['Name', 'Age', '1v1', 'Aer', 'Agi', 'Cmd', 'Com', 'Han', 'Kic', 'Pos', 'Ref', 'Thr', 'Cmp', 'Fir', 'Pas', 'TRO', 'Acc', 'Vis', 'Sweeper Keeper']]

##Defenders
wide_centre_back = df[['Name', 'Age', 'Fir', 'Hea', 'Mar', 'Pas', 'Tck', 'Agg', 'Ant', 'Bra', 'Cmp', 'Cnt', 'Dec', 'OtB', 'Pos', 'Wor', 'Jum', 'Pac', 'Sta', 'Str', 'Wide Centre Back']]
central_defender = df[['Name', 'Age', 'Hea', 'Mar', 'Tck', 'Agg', 'Ant', 'Bra', 'Cmp', 'Cnt', 'Dec', 'Pos', 'Jum', 'Pac', 'Str', 'Central Defender']]
libero = df[['Name', 'Age', 'Dri', 'Fir', 'Hea', 'Lon', 'Mar', 'Pas', 'Tck', 'Tec', 'Ant', 'Bra', 'Cmp', 'Cnt', 'Dec', 'Fla', 'Pos', 'Tea', 'Vis', 'Acc', 'Agi', 'Bal', 'Jum', 'Pac', 'Sta', 'Str', 'Libero']]
ball_playing_defender = df[['Name', 'Age', 'Fir', 'Hea', 'Mar', 'Pas', 'Tck', 'Tec', 'Agg', 'Ant', 'Bra', 'Cmp', 'Cnt', 'Dec', 'Pos', 'Vis', 'Jum', 'Pac', 'Str', 'Ball-Playing Defender']]
no_nonsense_centre_back = df[['Name', 'Age', 'Hea', 'Mar', 'Tck', 'Agg', 'Ant', 'Bra', 'Cmp', 'Cnt', 'Pos', 'Jum', 'Pac', 'Str', 'No-Nonsense Centre Back']]

##Midfield
defensive_midfielder = df[['Name', 'Age', 'Fir', 'Mar', 'Pas', 'Tck', 'Agg', 'Ant', 'Cmp', 'Cnt', 'Dec', 'Pos', 'Tea', 'Wor', 'Sta', 'Str', 'Defensive Midfielder']]
deep_lying_playmaker = df[['Name', 'Age', 'Fir', 'Pas', 'Tec', 'Ant', 'Cmp', 'Dec', 'OtB', 'Tea', 'Vis', 'Wor', 'Bal', 'Deep-Lying Playmaker']]
ball_winning_midfielder = df[['Name', 'Age', 'Fir', 'Mar', 'Pas', 'Tck', 'Agg', 'Ant', 'Cmp', 'Cnt', 'Dec', 'Pos', 'Tea', 'Wor', 'Sta', 'Str', 'Ball-Winnining Midfielder']]
anchor_man = df[['Name', 'Age', 'Mar', 'Tck', 'Ant', 'Cmp', 'Cnt', 'Dec', 'Pos', 'Tea', 'Str', 'Anchor Man']]
half_back = df[['Name', 'Age', 'Fir', 'Mar', 'Pas', 'Tck', 'Tec', 'Agg', 'Ant', 'Cmp', 'Cnt', 'Dec', 'Pos', 'Tea', 'Wor', 'Sta', 'Half Back']]
regista = df[['Name', 'Age', 'Dri', 'Fir', 'Lon', 'Pas', 'Tec', 'Ant', 'Cmp', 'Dec', 'Fla', 'OtB', 'Tea', 'Vis', 'Bal', 'Regista']]
roaming_playmaker = df[['Name', 'Age', 'Dri', 'Fir', 'Lon', 'Pas', 'Tec', 'Ant', 'Cmp', 'Cnt', 'Dec', 'OtB', 'Pos', 'Tea', 'Vis', 'Wor', 'Acc', 'Agi', 'Bal', 'Pac', 'Sta', 'Roaming Playmaker']]
segundo_volante = df[['Name', 'Age', 'Fin', 'Fir', 'Lon', 'Mar', 'Pas', 'Tck', 'Ant', 'Cmp', 'Cnt', 'Dec', 'OtB', 'Pos', 'Wor', 'Acc', 'Bal', 'Pac', 'Sta', 'Str', 'Segundo Volante']]
central_midfielder = df[['Name', 'Age', 'Fir', 'Lon', 'Pas', 'Tck', 'Tec', 'Ant', 'Cmp', 'Dec', 'OtB', 'Tea', 'Vis', 'Wor', 'Acc', 'Sta', 'Central Midfielder']]
box_to_box_midfielder = df[['Name', 'Age', 'Dri', 'Fin', 'Fir', 'Lon', 'Pas', 'Tck', 'Tec', 'Agg', 'Ant', 'Cmp', 'Dec', 'OtB', 'Pos', 'Tea', 'Vis', 'Wor', 'Acc', 'Bal', 'Pac', 'Sta', 'Str', 'Box-To-Box Midfielder']]
advanced_playmaker = df[['Name', 'Age', 'Dri', 'Fir', 'Pas', 'Tec', 'Ant', 'Cmp', 'Dec', 'Fla', 'OtB', 'Tea', 'Vis', 'Acc', 'Agi', 'Advanced Playmaker']]
mezzala = df[['Name', 'Age', 'Dri', 'Fin', 'Fir', 'Lon', 'Pas', 'Tec', 'Ant', 'Cmp', 'Dec', 'Fla', 'OtB', 'Vis', 'Wor', 'Acc', 'Bal', 'Sta', 'Mezzala']]
carrilero = df[['Name', 'Age', 'Fir', 'Pas', 'Tck', 'Tec', 'Ant', 'Cmp', 'Cnt', 'Dec', 'OtB', 'Pos', 'Tea', 'Vis', 'Wor', 'Sta', 'Carrilero']]
attacking_midfielder = df[['Name', 'Age', 'Dri', 'Fir', 'Lon', 'Pas', 'Tec', 'Ant', 'Cmp', 'Dec', 'Fla', 'OtB', 'Vis', 'Agi', 'Attacking Midfielder']]
terquartista = df[['Name', 'Age', 'Dri', 'Fin', 'Fir', 'Pas', 'Tec', 'Ant', 'Cmp', 'Dec', 'Fla', 'OtB', 'Vis', 'Acc', 'Agi', 'Bal', 'Terquartista']]
enganche = df[['Name', 'Age', 'Fir', 'Pas', 'Tec', 'Ant', 'Cmp', 'Dec', 'Fla', 'OtB', 'Vis', 'Bal', 'Enganche']]
shadow_striker = df[['Name', 'Age', 'Dri', 'Fin', 'Fir', 'Pas', 'Tec', 'Ant', 'Cmp', 'Cnt', 'Dec', 'OtB', 'Wor', 'Acc', 'Agi', 'Bal', 'Pac', 'Sta', 'Shadow Striker']]

##Flanks
wide_midfielder = df[['Name', 'Age', 'Cro', 'Fir', 'Pas', 'Tck', 'Tec', 'Ant', 'Cmp', 'Cnt', 'Dec', 'OtB', 'Pos', 'Tea', 'Vis', 'Wor', 'Sta', 'Wide Midfielder']]
winger = df[['Name', 'Age', 'Cro', 'Dri', 'Fir', 'Pas', 'Tec', 'Ant', 'Fla', 'OtB', 'Wor', 'Acc', 'Agi', 'Bal', 'Pac', 'Sta', 'Winger']]
defensive_winger = df[['Name', 'Age', 'Cro', 'Dri', 'Fir', 'Mar', 'Pas', 'Tec', 'Tck', 'Agg', 'Ant', 'Cmp', 'Cnt', 'Dec', 'OtB', 'Pos', 'Tea', 'Wor', 'Acc', 'Sta', 'Defensive Winger']]
wide_playmaker = df[['Name', 'Age', 'Dri', 'Fir', 'Pas', 'Tec', 'Ant', 'Cmp', 'Dec', 'Fla', 'OtB', 'Tea', 'Vis', 'Acc', 'Agi', 'Wide Playmaker']]
inverted_winger = df[['Name', 'Age', 'Cro', 'Dri', 'Fir', 'Lon', 'Pas', 'Tec', 'Ant', 'Cmp', 'Dec', 'Fla', 'OtB', 'Vis', 'Wor', 'Acc', 'Agi', 'Bal', 'Pac', 'Sta', 'Inverted Winger']]
inside_forward = df[['Name', 'Age', 'Dri', 'Fin', 'Fir', 'Lon', 'Pas', 'Tec', 'Ant', 'Cmp', 'Fla', 'OtB', 'Wor', 'Acc', 'Agi', 'Bal', 'Pac', 'Sta', 'Inside Forward']]
wide_target_man = df[['Name', 'Age', 'Cro', 'Fin', 'Fir', 'Hea', 'Ant', 'Bra', 'OtB', 'Tea', 'Wor', 'Bal', 'Jum', 'Sta', 'Str', 'Wide Target Man']]
raumdeuter = df[['Name', 'Age', 'Fin', 'Fir', 'Tec', 'Ant', 'Cmp', 'Cnt', 'Dec', 'OtB', 'Wor', 'Acc', 'Bal', 'Sta', 'Raumdeuter']]

##Attack
deep_lying_forward = df[['Name', 'Age', 'Fin', 'Fir', 'Pas', 'Tec', 'Ant', 'Cmp', 'Dec', 'Fla', 'OtB', 'Tea', 'Vis', 'Bal', 'Str', 'Deep-Lying Forward']]
advanced_forward = df[['Name', 'Age', 'Dri', 'Fin', 'Fir', 'Pas', 'Tec', 'Ant', 'Cmp', 'Dec', 'OtB', 'Wor', 'Acc', 'Agi', 'Bal', 'Pac', 'Sta', 'Advanced Forward']]
target_forward = df[['Name', 'Age', 'Fin', 'Fir', 'Hea', 'Agg', 'Ant', 'Bra', 'Cmp', 'Dec', 'OtB', 'Tea', 'Bal', 'Jum', 'Str', 'Target Forward']]
false_9 = df[['Name', 'Age', 'Dri', 'Fin', 'Fir', 'Pas', 'Tec', 'Ant', 'Cmp', 'Dec', 'Fla', 'OtB', 'Tea', 'Vis', 'Acc', 'Agi', 'Bal', 'False 9']]
poacher = df[['Name', 'Age', 'Fin', 'Fir', 'Hea', 'Tec', 'Ant', 'Cmp', 'Dec', 'OtB', 'Acc', 'Poacher']]
complete_forward = df[['Name', 'Age', 'Dri', 'Fin', 'Fir', 'Hea', 'Lon', 'Pas', 'Tec', 'Ant', 'Cmp', 'Dec', 'OtB', 'Tea', 'Vis', 'Wor', 'Acc', 'Agi', 'Bal', 'Jum', 'Pac', 'Sta', 'Str', 'Complete Forward']]
pressing_forward = df[['Name', 'Age', 'Fin', 'Fir', 'Agg', 'Ant', 'Bra', 'Cmp', 'Cnt', 'Dec', 'OtB', 'Tea', 'Wor', 'Acc', 'Agi', 'Bal', 'Pac', 'Sta', 'Str', 'Pressing Forward']]

# %%
print("Club DNA")
sorted_dna = dna.sort_values(by='Club DNA', ascending=False)
sorted_dna.head(50).style.hide(axis='index')\
    .background_gradient(cmap='Greens')
# Out:
# Club DNA
# <style type="text/css">
# #T_3718b_row0_col1, #T_3718b_row37_col1 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_3718b_row0_col2, #T_3718b_row1_col5, #T_3718b_row4_col2, #T_3718b_row5_col5 {
#   background-color: #18823d;
#   color: #f1f1f1;
# }
# #T_3718b_row0_col3, #T_3718b_row0_col7, #T_3718b_row1_col4, #T_3718b_row1_col6, #T_3718b_row2_col3, #T_3718b_row2_col4, #T_3718b_row3_col2, #T_3718b_row3_col3, #T_3718b_row7_col5, #T_3718b_row31_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_3718b_row0_col4, #T_3718b_row2_col7 {
#   background-color: #005522;
#   color: #f1f1f1;
# }
# #T_3718b_row0_col5, #T_3718b_row3_col5, #T_3718b_row4_col5, #T_3718b_row12_col5 {
#   background-color: #005b25;
#   color: #f1f1f1;
# }
# #T_3718b_row0_col6 {
#   background-color: #157f3b;
#   color: #f1f1f1;
# }
# ...

# %%
print("Goalkeeper")
sorted_gk = goalkeeper.sort_values(by='Goalkeeper', ascending=False)
sorted_gk.head(5).style.hide(axis='index')\
                .background_gradient(cmap='Blues')
# Out:
# Goalkeeper
# <style type="text/css">
# #T_3d1a5_row0_col1, #T_3d1a5_row0_col2, #T_3d1a5_row0_col5, #T_3d1a5_row0_col6, #T_3d1a5_row0_col10, #T_3d1a5_row0_col11, #T_3d1a5_row0_col12, #T_3d1a5_row1_col3, #T_3d1a5_row1_col7, #T_3d1a5_row1_col8, #T_3d1a5_row1_col9, #T_3d1a5_row2_col4, #T_3d1a5_row3_col1, #T_3d1a5_row3_col9 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_3d1a5_row0_col3 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_3d1a5_row0_col4, #T_3d1a5_row1_col5 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_3d1a5_row0_col7 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_3d1a5_row0_col8 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# ...

# %%
print("Sweeper Keeper")
sorted_sk = sweeper_keeper.sort_values(by='Sweeper Keeper', ascending=False)
sorted_sk.head(5).style.hide(axis='index')\
                  .background_gradient(cmap='Blues')
# Out:
# Sweeper Keeper
# <style type="text/css">
# #T_ec53d_row0_col1, #T_ec53d_row0_col4, #T_ec53d_row0_col12, #T_ec53d_row1_col13, #T_ec53d_row1_col14, #T_ec53d_row1_col17, #T_ec53d_row2_col3, #T_ec53d_row2_col6, #T_ec53d_row2_col8, #T_ec53d_row2_col12, #T_ec53d_row2_col15, #T_ec53d_row2_col18, #T_ec53d_row3_col1, #T_ec53d_row3_col2, #T_ec53d_row3_col3, #T_ec53d_row3_col7, #T_ec53d_row3_col9, #T_ec53d_row3_col10, #T_ec53d_row3_col11, #T_ec53d_row3_col12, #T_ec53d_row3_col18, #T_ec53d_row4_col1, #T_ec53d_row4_col2, #T_ec53d_row4_col4, #T_ec53d_row4_col5, #T_ec53d_row4_col6, #T_ec53d_row4_col16, #T_ec53d_row4_col18 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_ec53d_row0_col2, #T_ec53d_row1_col18, #T_ec53d_row3_col14 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# ...

# %%
print("Wide Centre Back")
sorted_wcb = wide_centre_back.sort_values(by='Wide Centre Back', ascending=False)
sorted_wcb.head(5).style.hide(axis='index')\
                  .background_gradient(cmap='Accent')
# Out:
# Wide Centre Back
# <style type="text/css">
# #T_2aa4b_row0_col1, #T_2aa4b_row0_col2, #T_2aa4b_row0_col3, #T_2aa4b_row0_col7, #T_2aa4b_row0_col9, #T_2aa4b_row0_col13, #T_2aa4b_row0_col16, #T_2aa4b_row0_col18, #T_2aa4b_row0_col19, #T_2aa4b_row0_col20, #T_2aa4b_row1_col1, #T_2aa4b_row1_col4, #T_2aa4b_row1_col6, #T_2aa4b_row1_col11, #T_2aa4b_row1_col12, #T_2aa4b_row1_col14, #T_2aa4b_row1_col16, #T_2aa4b_row1_col19, #T_2aa4b_row1_col20, #T_2aa4b_row2_col5, #T_2aa4b_row2_col16, #T_2aa4b_row3_col9, #T_2aa4b_row3_col15, #T_2aa4b_row3_col17, #T_2aa4b_row3_col19, #T_2aa4b_row4_col8, #T_2aa4b_row4_col10, #T_2aa4b_row4_col12, #T_2aa4b_row4_col18 {
#   background-color: #666666;
#   color: #f1f1f1;
# }
# #T_2aa4b_row0_col4, #T_2aa4b_row2_col20, #T_2aa4b_row3_col14, #T_2aa4b_row4_col5 {
#   background-color: #beaed4;
#   color: #000000;
# }
# ...

# %%
print("Central Defender")
sorted_cd = central_defender.sort_values(by='Central Defender', ascending=False)
sorted_cd.head(5).style.hide(axis='index')\
                  .background_gradient(cmap='Accent')
# Out:
# Central Defender
# <style type="text/css">
# #T_c4655_row0_col1, #T_c4655_row0_col3, #T_c4655_row0_col4, #T_c4655_row0_col9, #T_c4655_row0_col10, #T_c4655_row0_col11, #T_c4655_row0_col12, #T_c4655_row0_col14, #T_c4655_row0_col15, #T_c4655_row1_col1, #T_c4655_row1_col2, #T_c4655_row1_col5, #T_c4655_row1_col7, #T_c4655_row1_col12, #T_c4655_row1_col14, #T_c4655_row2_col7, #T_c4655_row2_col13, #T_c4655_row2_col14, #T_c4655_row3_col12, #T_c4655_row4_col6, #T_c4655_row4_col8, #T_c4655_row4_col10 {
#   background-color: #666666;
#   color: #f1f1f1;
# }
# #T_c4655_row0_col2, #T_c4655_row0_col7, #T_c4655_row0_col8, #T_c4655_row1_col13, #T_c4655_row2_col3, #T_c4655_row3_col6, #T_c4655_row4_col5, #T_c4655_row4_col13 {
#   background-color: #f0027f;
#   color: #f1f1f1;
# }
# #T_c4655_row0_col5, #T_c4655_row1_col4, #T_c4655_row2_col4, #T_c4655_row2_col5, #T_c4655_row3_col1, #T_c4655_row3_col11, #T_c4655_row3_col14, #T_c4655_row4_col9 {
#   background-color: #386cb0;
#   color: #f1f1f1;
# }
# ...

# %%
print("Libero")
sorted_li = libero.sort_values(by='Libero', ascending=False)
sorted_li.head(5).style.hide(axis='index')\
                  .background_gradient(cmap='Accent')
# Out:
# Libero
# <style type="text/css">
# #T_b88a8_row0_col1, #T_b88a8_row0_col2, #T_b88a8_row0_col6, #T_b88a8_row0_col8, #T_b88a8_row0_col13, #T_b88a8_row0_col16, #T_b88a8_row0_col21, #T_b88a8_row0_col22, #T_b88a8_row0_col23, #T_b88a8_row0_col25, #T_b88a8_row0_col26, #T_b88a8_row1_col1, #T_b88a8_row1_col2, #T_b88a8_row1_col4, #T_b88a8_row1_col11, #T_b88a8_row1_col19, #T_b88a8_row1_col22, #T_b88a8_row1_col24, #T_b88a8_row1_col25, #T_b88a8_row1_col26, #T_b88a8_row2_col2, #T_b88a8_row2_col3, #T_b88a8_row2_col5, #T_b88a8_row2_col7, #T_b88a8_row2_col9, #T_b88a8_row2_col12, #T_b88a8_row2_col14, #T_b88a8_row2_col15, #T_b88a8_row2_col17, #T_b88a8_row2_col18, #T_b88a8_row3_col11, #T_b88a8_row3_col22, #T_b88a8_row4_col2, #T_b88a8_row4_col8, #T_b88a8_row4_col10, #T_b88a8_row4_col12, #T_b88a8_row4_col14, #T_b88a8_row4_col20, #T_b88a8_row4_col24 {
#   background-color: #666666;
#   color: #f1f1f1;
# }
# ...

# %%
print("Ball Playing Defender")
sorted_bpd = ball_playing_defender.sort_values(by='Ball-Playing Defender', ascending=False)
sorted_bpd.head(5).style.hide(axis='index')\
                  .background_gradient(cmap='Accent')
# Out:
# Ball Playing Defender
# <style type="text/css">
# #T_3943f_row0_col1, #T_3943f_row0_col4, #T_3943f_row0_col6, #T_3943f_row0_col12, #T_3943f_row0_col14, #T_3943f_row0_col16, #T_3943f_row0_col17, #T_3943f_row0_col18, #T_3943f_row0_col19, #T_3943f_row1_col1, #T_3943f_row1_col3, #T_3943f_row1_col8, #T_3943f_row1_col10, #T_3943f_row1_col16, #T_3943f_row1_col18, #T_3943f_row2_col10, #T_3943f_row2_col16, #T_3943f_row3_col6, #T_3943f_row3_col9, #T_3943f_row3_col11, #T_3943f_row3_col13, #T_3943f_row4_col2, #T_3943f_row4_col5, #T_3943f_row4_col7, #T_3943f_row4_col11, #T_3943f_row4_col13, #T_3943f_row4_col15 {
#   background-color: #666666;
#   color: #f1f1f1;
# }
# ...

# %%
print("No-Nonsense Centre Back")
sorted_ncb = no_nonsense_centre_back.sort_values(by='No-Nonsense Centre Back', ascending=False)
sorted_ncb.head(5).style.hide(axis='index')\
                  .background_gradient(cmap='Accent')
# Out:
# No-Nonsense Centre Back
# <style type="text/css">
# #T_2cf2f_row0_col1, #T_2cf2f_row0_col3, #T_2cf2f_row0_col4, #T_2cf2f_row0_col9, #T_2cf2f_row0_col10, #T_2cf2f_row0_col11, #T_2cf2f_row0_col13, #T_2cf2f_row0_col14, #T_2cf2f_row1_col1, #T_2cf2f_row1_col2, #T_2cf2f_row1_col5, #T_2cf2f_row1_col7, #T_2cf2f_row1_col11, #T_2cf2f_row1_col13, #T_2cf2f_row2_col7, #T_2cf2f_row2_col12, #T_2cf2f_row2_col13, #T_2cf2f_row3_col11, #T_2cf2f_row4_col6, #T_2cf2f_row4_col8 {
#   background-color: #666666;
#   color: #f1f1f1;
# }
# #T_2cf2f_row0_col2, #T_2cf2f_row0_col7, #T_2cf2f_row0_col8, #T_2cf2f_row1_col12, #T_2cf2f_row2_col3, #T_2cf2f_row3_col6, #T_2cf2f_row4_col5, #T_2cf2f_row4_col12 {
#   background-color: #f0027f;
#   color: #f1f1f1;
# }
# #T_2cf2f_row0_col5, #T_2cf2f_row1_col4, #T_2cf2f_row1_col14, #T_2cf2f_row2_col4, #T_2cf2f_row2_col5, #T_2cf2f_row2_col14, #T_2cf2f_row3_col1, #T_2cf2f_row3_col10, #T_2cf2f_row3_col13, #T_2cf2f_row4_col9 {
#   background-color: #386cb0;
#   color: #f1f1f1;
# ...

# %%
print("Defensive Midfielder")
sorted_dm = defensive_midfielder.sort_values(by='Defensive Midfielder', ascending=False)
sorted_dm.head(5).style.hide(axis='index')\
    .background_gradient(cmap='GnBu')
# Out:
# Defensive Midfielder
# <style type="text/css">
# #T_13fc5_row0_col1, #T_13fc5_row0_col3, #T_13fc5_row0_col5, #T_13fc5_row0_col9, #T_13fc5_row0_col11, #T_13fc5_row0_col16, #T_13fc5_row1_col1, #T_13fc5_row1_col2, #T_13fc5_row1_col6, #T_13fc5_row1_col12, #T_13fc5_row1_col14, #T_13fc5_row2_col7, #T_13fc5_row2_col8, #T_13fc5_row2_col10, #T_13fc5_row2_col12, #T_13fc5_row2_col14, #T_13fc5_row3_col4, #T_13fc5_row3_col12, #T_13fc5_row4_col13, #T_13fc5_row4_col15 {
#   background-color: #084081;
#   color: #f1f1f1;
# }
# #T_13fc5_row0_col2, #T_13fc5_row0_col7, #T_13fc5_row1_col9, #T_13fc5_row1_col11, #T_13fc5_row2_col1, #T_13fc5_row2_col3, #T_13fc5_row2_col13, #T_13fc5_row2_col15, #T_13fc5_row3_col5, #T_13fc5_row3_col6, #T_13fc5_row3_col14, #T_13fc5_row4_col1, #T_13fc5_row4_col4, #T_13fc5_row4_col8, #T_13fc5_row4_col10, #T_13fc5_row4_col12, #T_13fc5_row4_col16 {
#   background-color: #f7fcf0;
#   color: #000000;
# }
# #T_13fc5_row0_col4 {
#   background-color: #9fdab8;
#   color: #000000;
# }
# ...

# %%
print("Deep Lying Playmaker")
sorted_dm = deep_lying_playmaker.sort_values(by='Deep-Lying Playmaker', ascending=False)
sorted_dm.head(5).style.hide(axis='index')\
    .background_gradient(cmap='GnBu')
# Out:
# Deep Lying Playmaker
# <style type="text/css">
# #T_99a95_row0_col1, #T_99a95_row1_col1, #T_99a95_row1_col5, #T_99a95_row1_col11, #T_99a95_row1_col12, #T_99a95_row2_col1, #T_99a95_row2_col2, #T_99a95_row2_col3, #T_99a95_row2_col6, #T_99a95_row3_col2, #T_99a95_row3_col4, #T_99a95_row3_col7, #T_99a95_row3_col10, #T_99a95_row4_col2, #T_99a95_row4_col8, #T_99a95_row4_col9, #T_99a95_row4_col12, #T_99a95_row4_col13 {
#   background-color: #f7fcf0;
#   color: #000000;
# }
# #T_99a95_row0_col2, #T_99a95_row0_col3, #T_99a95_row0_col4, #T_99a95_row0_col5, #T_99a95_row0_col6, #T_99a95_row0_col7, #T_99a95_row0_col9, #T_99a95_row0_col10, #T_99a95_row0_col13, #T_99a95_row1_col2, #T_99a95_row1_col10, #T_99a95_row2_col4, #T_99a95_row2_col7, #T_99a95_row2_col8, #T_99a95_row3_col1, #T_99a95_row3_col11, #T_99a95_row3_col12, #T_99a95_row4_col1 {
#   background-color: #084081;
#   color: #f1f1f1;
# }
# #T_99a95_row0_col8, #T_99a95_row4_col5 {
#   background-color: #b4e2ba;
#   color: #000000;
# }
# ...
